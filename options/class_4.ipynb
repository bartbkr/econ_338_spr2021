# %%
import yfinance as yf

# %%
tesla = yf.Ticker('TSLA')

# %%
tesla.info
# Out:
# {'zip': '94304',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 70757,
# ...

# %%
tesla.options
# Out:
# ('2021-03-12',
#  '2021-03-19',
#  '2021-03-26',
#  '2021-04-01',
#  '2021-04-09',
#  '2021-04-16',
#  '2021-04-23',
#  '2021-05-21',
#  '2021-06-18',
#  '2021-07-16',
#  '2021-09-17',
#  '2021-12-17',
#  '2022-01-21',
#  '2022-03-18',
#  '2022-06-17',
#  '2022-09-16',
#  '2023-01-20',
#  '2023-03-17')

# %%
tesla.option_chain('2021-06-18')
# Out:
# Options(calls=          contractSymbol       lastTradeDate  strike  lastPrice     bid  \
# 0    TSLA210618C00001000 2021-03-04 15:10:23     1.0     702.55  663.80
# 1    TSLA210618C00002000 2021-03-04 15:15:15     2.0     623.45  662.80
# 2    TSLA210618C00003000 2021-01-08 15:00:48     3.0     854.43  847.15
# 3    TSLA210618C00004000 2021-03-05 14:58:04     4.0     582.80  660.80
# 4    TSLA210618C00005000 2020-11-03 20:01:18     5.0     419.06  592.00
# ..                   ...                 ...     ...        ...     ...
# 409  TSLA210618C03600000 2020-08-28 17:46:45  3600.0     273.78  256.00
# 410  TSLA210618C03700000 2020-08-28 16:15:36  3700.0     280.03  242.50
# 411  TSLA210618C03800000 2020-08-28 19:40:55  3800.0     248.28  229.50
# 412  TSLA210618C03900000 2020-08-28 19:04:38  3900.0     234.10  218.00
# 413  TSLA210618C04000000 2020-08-28 19:40:18  4000.0     223.21  207.00
#
#         ask     change  percentChange  volume  openInterest  \
# ...

# %%
calls = tesla.option_chain('2021-06-18').calls

# %%
calls
# Out:
#           contractSymbol       lastTradeDate  strike  lastPrice     bid  \
# 0    TSLA210618C00001000 2021-03-04 15:10:23     1.0     702.55  663.80
# 1    TSLA210618C00002000 2021-03-04 15:15:15     2.0     623.45  662.80
# 2    TSLA210618C00003000 2021-01-08 15:00:48     3.0     854.43  847.15
# 3    TSLA210618C00004000 2021-03-05 14:58:04     4.0     582.80  660.80
# 4    TSLA210618C00005000 2020-11-03 20:01:18     5.0     419.06  592.00
# ..                   ...                 ...     ...        ...     ...
# 409  TSLA210618C03600000 2020-08-28 17:46:45  3600.0     273.78  256.00
# 410  TSLA210618C03700000 2020-08-28 16:15:36  3700.0     280.03  242.50
# 411  TSLA210618C03800000 2020-08-28 19:40:55  3800.0     248.28  229.50
# 412  TSLA210618C03900000 2020-08-28 19:04:38  3900.0     234.10  218.00
# 413  TSLA210618C04000000 2020-08-28 19:40:18  4000.0     223.21  207.00
#
#         ask     change  percentChange  volume  openInterest  \
# ...

# %%
calls.sort?
# Out:
# Object `calls.sort` not found.

# %%
calls.sort_column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-8d25ae2148dd> in <module>
# ----> 1 calls.sort_column
#
# ~\Anaconda3\envs\econ338jupyter\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort_column'

# %%
calls.sort_values(columns=['lastTradeDate'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-01ef98c2ab7d> in <module>
# ----> 1 calls.sort_values(columns=['lastTradeDate'], inplace=True)
#
# TypeError: sort_values() got an unexpected keyword argument 'columns'

# %%
calls.sort_values(['lastTradeDate'], inplace=True)

# %%
calls
# Out:
#           contractSymbol       lastTradeDate  strike  lastPrice     bid  \
# 301  TSLA210618C01015000 2020-06-25 15:56:01  1015.0     219.00  557.00
# 95   TSLA210618C00115000 2020-07-09 20:54:19   115.0     658.40    0.00
# 101  TSLA210618C00125000 2020-07-09 20:54:20   125.0     406.85    0.00
# 107  TSLA210618C00135000 2020-07-09 20:54:21   135.0     827.75    0.00
# 113  TSLA210618C00145000 2020-07-09 20:54:22   145.0     385.00    0.00
# ..                   ...                 ...     ...        ...     ...
# 287  TSLA210618C00900000 2021-03-10 20:57:48   900.0      38.00   36.95
# 266  TSLA210618C00690000 2021-03-10 20:58:40   690.0      96.91   95.90
# 320  TSLA210618C01200000 2021-03-10 20:58:44  1200.0      11.65   11.05
# 262  TSLA210618C00650000 2021-03-10 20:59:07   650.0     114.50  113.35
# 277  TSLA210618C00800000 2021-03-10 20:59:43   800.0      60.05   59.00
#
#         ask    change  percentChange  volume  openInterest  impliedVolatility  \
# ...

# %%
import pandas as pd

# %%
strikes = pd.Series(calls['strike'])

# %%
strikes
# Out:
# 301    1015.0
# 95      115.0
# 101     125.0
# 107     135.0
# 113     145.0
#         ...
# 287     900.0
# 266     690.0
# 320    1200.0
# 262     650.0
# 277     800.0
# Name: strike, Length: 414, dtype: float64
